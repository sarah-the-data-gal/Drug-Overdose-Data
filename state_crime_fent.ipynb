# %%
import pandas as pd
import numpy as np

# %%
crime = pd.read_csv('state_crime.csv')

# %%
crime.head()
# Out:
#      State  Year  Data.Population  Data.Rates.Property.All  \
# 0  Alabama  2015          4858979                   2978.9
# 1  Alabama  2016          4863300                   2947.8
# 2  Alabama  2017          4874747                   2957.3
# 3  Alabama  2018          4887871                   2817.2
# 4  Alabama  2019          4903185                   2674.4
#
#    Data.Rates.Property.Burglary  Data.Rates.Property.Larceny  \
# 0                         725.6                       2040.7
# 1                         700.5                       2006.3
# 2                         645.7                       2048.1
# 3                         590.1                       1958.9
# 4                         531.9                       1886.1
#
#    Data.Rates.Property.Motor  Data.Rates.Violent.All  \
# 0                      212.7                   472.4
# 1                      241.1                   532.3
# 2                      263.4                   524.2
# ...

# %%
columns_to_keep= ['State','Year', 'Data.Population',"Data.Rates.Violent.All"]
crime= pd.read_csv('state_crime.csv', usecols=columns_to_keep)

# %%
# checking for missing values
crime.isnull().sum()
# Out:
# State                            0
# Year                             0
# Data.Population                  0
# Data.Rates.Property.All          0
# Data.Rates.Property.Burglary     0
# Data.Rates.Property.Larceny      0
# Data.Rates.Property.Motor        0
# Data.Rates.Violent.All           0
# Data.Rates.Violent.Assault       0
# Data.Rates.Violent.Murder        0
# Data.Rates.Violent.Rape          0
# Data.Rates.Violent.Robbery       0
# Data.Totals.Property.All         0
# Data.Totals.Property.Burglary    0
# Data.Totals.Property.Larceny     0
# Data.Totals.Property.Motor       0
# Data.Totals.Violent.All          0
# Data.Totals.Violent.Assault      0
# Data.Totals.Violent.Murder       0
# Data.Totals.Violent.Rape         0
# Data.Totals.Violent.Robbery      0
# dtype: int64

# %%
# checking for duplicates
crime.duplicated().sum()
# Out:
# 0

# %%
# filtering to only keep the year between 2015-2019
years_to_keep= list(range(2015,2019))
crime_filtered = crime[crime['Year'].isin(years_to_keep)]

# %%
years_to_drop= [str(year) for year in range(1960, 2019)]
crime_filtered = crime.drop(columns=[col for col in crime.columns if col in years_to_drop])
print(crime_filtered)
# Out:
#         State  Year  Data.Population  Data.Rates.Violent.All
# 0     Alabama  2015          4858979                   472.4
# 1     Alabama  2016          4863300                   532.3
# 2     Alabama  2017          4874747                   524.2
# 3     Alabama  2018          4887871                   519.6
# 4     Alabama  2019          4903185                   510.8
# ...       ...   ...              ...                     ...
# 2890  Wyoming  2015           586107                   222.1
# 2891  Wyoming  2016           585501                   244.2
# 2892  Wyoming  2017           579315                   237.5
# 2893  Wyoming  2018           577737                   212.2
# 2894  Wyoming  2019           578759                   217.4
#
# [2895 rows x 4 columns]

# %%
crime_filtered.to_csv('filtered_crime_data.csv', index=False)
